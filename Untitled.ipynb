# %%
from hokusai.lib.template_renderer import TemplateRenderer

template = TemplateRenderer('./test/fixtures/kubernetes-config.yml', "s3://artsy-citadel/k8s/hokusai_vars.yml")
print(template.insert_variables())
# Out:
# ---
# apiVersion: extensions/v1beta1
# kind: Deployment
# metadata:
#   name: project-name-web
#   namespace: default
# spec:
#   strategy:
#     rollingUpdate:
#       maxSurge: 1
#       maxUnavailable: 0
#     type: RollingUpdate
#   template:
#     metadata:
#       labels:
#         app: project-name
#         component: web
#         layer: application
#       name: project-name-web
#     spec:
#       containers:
#         - name: project-name-web
#           env:
#             - name: RAILS_SERVE_STATIC_FILES
#               value: "true"
#             - name: RAILS_LOG_TO_STDOUT
#               value: "true"
#             - name: PUMA_BIND
#               value: "tcp://0.0.0.0:8080"
#             - name: DD_TRACE_AGENT_HOSTNAME
#               valueFrom:
#                 fieldRef:
#                   fieldPath: spec.nodeName
#           envFrom:
#             - configMapRef:
#                 name: project-name-environment
# ...
